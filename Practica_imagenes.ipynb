# %% [markdown]
# <a href="https://colab.research.google.com/github/JessicaGtz21/regresi-n-lineal-homicidios-/blob/main/Practica_imagenes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np 
from matplotlib import pyplot as plt

# %%
img =cv2.imread("/cielo.jpg",0)

# %%
hist = cv2.calcHist([img],[0],None,[256],[0,256])
plt.plot(hist,color = 'gray')

plt.xlabel('intensidad de iluminacion')
plt.ylabel('cantidad de pixeles')
plt.show()

# %%
img = cv2.imread("/cielo.jpg")

color = ('b','g','r')

for i, c in enumerate(color):
  hist = cv2.calcHist([img], [i], None , [256], [0,256]) 
  plt.plot(hist, color = c)
  plt.xlim([0,256])

plt.show()

# %%
img =cv2.imread("/milanesa.jpg",0)

# %%
hist = cv2.calcHist([img],[0],None,[256],[0,256])
plt.plot(hist,color = 'gray')

plt.xlabel('intensidad de iluminacion')
plt.ylabel('cantidad de pixeles')
plt.show()

# %%
img = cv2.imread("/milanesa.jpg")

color = ('b','g','r')

for i, c in enumerate(color):
  hist = cv2.calcHist([img], [i], None , [256], [0,256]) 
  plt.plot(hist, color = c)
  plt.xlim([0,256])

plt.show()

# %%
img =cv2.imread("/milanesa1.jpg",0)

# %%
hist = cv2.calcHist([img],[0],None,[256],[0,256])
plt.plot(hist,color = 'gray')

plt.xlabel('intensidad de iluminacion')
plt.ylabel('cantidad de pixeles')
plt.show()

# %%
img = cv2.imread("/milanesa1.jpg")

color = ('b','g','r')

for i, c in enumerate(color):
  hist = cv2.calcHist([img], [i], None , [256], [0,256]) 
  plt.plot(hist, color = c)
  plt.xlim([0,256])

plt.show()

# %%
img =cv2.imread("/milanesa2.jpg",0)

# %%
hist = cv2.calcHist([img],[0],None,[256],[0,256])
plt.plot(hist,color = 'gray')

plt.xlabel('intensidad de iluminacion')
plt.ylabel('cantidad de pixeles')
plt.show()

# %%
img = cv2.imread("/milanesa2.jpg")

color = ('b','g','r')

for i, c in enumerate(color):
  hist = cv2.calcHist([img], [i], None , [256], [0,256]) 
  plt.plot(hist, color = c)
  plt.xlim([0,256])

plt.show()

# %%
img =cv2.imread("/milanesita.jpg",0)

# %%
hist = cv2.calcHist([img],[0],None,[256],[0,256])
plt.plot(hist,color = 'gray')

plt.xlabel('intensidad de iluminacion')
plt.ylabel('cantidad de pixeles')
plt.show()

# %%
img = cv2.imread("/milanesita.jpg")

color = ('b','g','r')

for i, c in enumerate(color):
  hist = cv2.calcHist([img], [i], None , [256], [0,256]) 
  plt.plot(hist, color = c)
  plt.xlim([0,256])

plt.show()

# %%
img =cv2.imread("/pozole.jpg",0)

# %%
hist = cv2.calcHist([img],[0],None,[256],[0,256])
plt.plot(hist,color = 'gray')

plt.xlabel('intensidad de iluminacion')
plt.ylabel('cantidad de pixeles')
plt.show()

# %%
img = cv2.imread("/pozole.jpg")

color = ('b','g','r')

for i, c in enumerate(color):
  hist = cv2.calcHist([img], [i], None , [256], [0,256]) 
  plt.plot(hist, color = c)
  plt.xlim([0,256])

plt.show()

# %%
img =cv2.imread("/pozolee.jpg",0)

# %%
hist = cv2.calcHist([img],[0],None,[256],[0,256])
plt.plot(hist,color = 'gray')

plt.xlabel('intensidad de iluminacion')
plt.ylabel('cantidad de pixeles')
plt.show()

# %%
img = cv2.imread("/pozolee.jpg")

color = ('b','g','r')

for i, c in enumerate(color):
  hist = cv2.calcHist([img], [i], None , [256], [0,256]) 
  plt.plot(hist, color = c)
  plt.xlim([0,256])

plt.show()

# %%
img =cv2.imread("/pozoole.jpg",0)

# %%
hist = cv2.calcHist([img],[0],None,[256],[0,256])
plt.plot(hist,color = 'gray')

plt.xlabel('intensidad de iluminacion')
plt.ylabel('cantidad de pixeles')
plt.show()

# %%
img = cv2.imread("/pozolee.jpg")

color = ('b','g','r')

for i, c in enumerate(color):
  hist = cv2.calcHist([img], [i], None , [256], [0,256]) 
  plt.plot(hist, color = c)
  plt.xlim([0,256])

plt.show()

# %%
img =cv2.imread("/pozol.jpg",0)

# %%
hist = cv2.calcHist([img],[0],None,[256],[0,256])
plt.plot(hist,color = 'gray')

plt.xlabel('intensidad de iluminacion')
plt.ylabel('cantidad de pixeles')
plt.show()

# %%
img = cv2.imread("/pozol.jpg")

color = ('b','g','r')

for i, c in enumerate(color):
  hist = cv2.calcHist([img], [i], None , [256], [0,256]) 
  plt.plot(hist, color = c)
  plt.xlim([0,256])

plt.show()

# %%
img =cv2.imread("/pozoli.jpg",0)

# %%
hist = cv2.calcHist([img],[0],None,[256],[0,256])
plt.plot(hist,color = 'gray')

plt.xlabel('intensidad de iluminacion')
plt.ylabel('cantidad de pixeles')
plt.show()

# %%
img = cv2.imread("/pozoli.jpg")

color = ('b','g','r')

for i, c in enumerate(color):
  hist = cv2.calcHist([img], [i], None , [256], [0,256]) 
  plt.plot(hist, color = c)
  plt.xlim([0,256])

plt.show()

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-38cdc409-e8eb-4f5b-8247-8007844a2d6d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-38cdc409-e8eb-4f5b-8247-8007844a2d6d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import zipfile
import io 
data = zipfile.ZipFile(io.BytesIO(uploaded['PRACTICA.zip']),'r')
data.extractall()

# %%
import cv2
import numpy as np 
import os
import matplotlib.pyplot as plt

# %%
ruta_dog="/content/PRACTICA/MILANESA"
dog_training = []
img_size = 80 #tamaño de imagenes
#definiremos un ciclo for para aplicarlo a cada una de las imagenes
for img in os.listdir(ruta_dog):
  img = cv2 .imread(os.path.join(ruta_dog, img))
  img_gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
  img_gray_resize = cv2.resize(img_gray, (img_size ,img_size))
  dog_training.append([img_gray_resize])

# %%
print(len(dog_training))
print(dog_training)
# Out:
# 5
# [[array([[ 66,  56,  59, ..., 137, 137, 133],
#        [ 65,  56,  57, ..., 136, 134, 133],
#        [ 58,  55,  60, ..., 137, 134, 133],
#        ...,
#        [ 70,  47,  53, ..., 249, 254, 235],
#        [ 83, 103,  83, ..., 252, 245, 183],
#        [ 72,  58,  69, ..., 253, 219, 145]], dtype=uint8)], [array([[251, 208, 157, ..., 252, 252, 251],
#        [251, 143, 145, ..., 252, 252, 252],
#        [217, 150, 134, ..., 252, 252, 251],
#        ...,
#        [214, 212, 213, ..., 246, 247, 248],
#        [210, 217, 203, ..., 246, 248, 248],
#        [208, 217, 203, ..., 247, 248, 248]], dtype=uint8)], [array([[237, 238, 241, ..., 185, 151, 150],
#        [238, 240, 244, ..., 241, 205, 140],
#        [240, 243, 244, ..., 247, 247, 223],
#        ...,
#        [165, 170, 166, ...,  51,  50,  55],
#        [180, 158, 162, ...,  55,  52,  54],
#        [180, 177, 168, ...,  59,  59,  61]], dtype=uint8)], [array([[12, 15, 24, ..., 56, 50, 40],
# ...

# %%
plt.figure()
plt.imshow(np.squeeze(dog_training[1]))
plt.colorbar()
plt.grid(False)
plt.show()

# %% [markdown]
# AHORA HAREMOS  LA CARPETA pOZOLE

# %%
ruta_dog="/content/PRACTICA/pOZOLE"
dog_training = []
img_size = 80 #tamaño de imagenes
#definiremos un ciclo for para aplicarlo a cada una de las imagenes
for img in os.listdir(ruta_dog):
  img = cv2 .imread(os.path.join(ruta_dog, img))
  img_gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
  img_gray_resize = cv2.resize(img_gray, (img_size ,img_size))
  dog_training.append([img_gray_resize])

# %%
print(len(dog_training))
print(dog_training)
# Out:
# 5
# [[array([[245, 245, 246, ...,  73,  38,  46],
#        [245, 245, 245, ...,  70,  36,  46],
#        [245, 245, 244, ...,  67,  34,  45],
#        ...,
#        [160, 136, 108, ...,  66,  68,  68],
#        [164, 154, 120, ...,  70,  72,  68],
#        [167, 156, 121, ...,  70,  75,  65]], dtype=uint8)], [array([[239, 243, 243, ..., 208, 203, 199],
#        [238, 243, 242, ..., 131, 210, 206],
#        [238, 242, 252, ..., 113, 135, 208],
#        ...,
#        [181, 203, 204, ..., 189, 191, 190],
#        [182, 190, 196, ..., 184, 190, 188],
#        [191, 183, 194, ..., 173, 199, 186]], dtype=uint8)], [array([[ 19,  42,  62, ..., 112,  17,  22],
#        [ 70,  59,  87, ..., 240, 229,  39],
#        [110,  80,  19, ..., 246, 238, 194],
#        ...,
#        [ 33,  29,  30, ..., 142,  68,  53],
#        [ 27,  38,  37, ...,  77,  46,  32],
#        [ 34,  34,  34, ...,  52,  37,  34]], dtype=uint8)], [array([[219, 217, 203, ...,  72,  45,  21],
# ...

# %%
plt.figure()
plt.imshow(np.squeeze(dog_training[4]))
plt.colorbar()
plt.grid(False)
plt.show()
