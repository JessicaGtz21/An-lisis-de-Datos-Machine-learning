# %% [markdown]
# <a href="https://colab.research.google.com/github/JessicaGtz21/An-lisis-de-Datos-Machine-learning/blob/main/KERNEL_IM%C3%81GENES_FILTROS_JMGG_LCDN_801.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ***Gutierrez Galvan Jessica Montserat.*** ***Práctica Kernel***

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

# %%
# Cargo la imagen mariposaazul
imagen = cv2.imread('/content/mariposaazul.jpg')

# %%
# Define el kernel para el filtro sharpen
kernel = np.array([[1,2,1],
                   [0,0,0.125],
                   [0.0625, 0.125, 0.625]])

# %%
# Aplico el filtro sharpen
image_sharpen = cv2.filter2D(imagen, -1, kernel)

# %%
# Mostrar la imagen original  y la iamgen sharpen
cv2_imshow(imagen)
cv2_imshow(image_sharpen)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=300x168>
# <PIL.Image.Image image mode=RGB size=300x168>

# %%
# Cargo la imagen mariposaazul
imagen = cv2.imread('/content/mariposaazul.jpg')

# %%
# Define el kernel para el filtro afilar
kernel = np.array([[0, -1, 0 ],
                   [-1, 5,-1 ],
                   [0, -1 , 0]])

# %%
# Aplico el filtro sharpen
image_sharpen = cv2.filter2D(imagen, -1, kernel)

# %%
# Mostrar la imagen original  y la iamgen sharpen
cv2_imshow(imagen)
cv2_imshow(image_sharpen)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=300x168>
# <PIL.Image.Image image mode=RGB size=300x168>

# %%
# Cargo la imagen mariposaazul
imagen = cv2.imread('/content/mariposaazul.jpg')

# %%
# Define el kernel para el filtro difuminar
kernel = np.array([[0.0625,0.125,0.0625],
                   [0.125, 0.25, 0.125],
                   [0.0625, 0.125, 0.0625]])

# %%
# Aplico el filtro sharpen
image_sharpen = cv2.filter2D(imagen, -1, kernel)

# %%
# Mostrar la imagen original  y la iamgen sharpen
cv2_imshow(imagen)
cv2_imshow(image_sharpen)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=300x168>
# <PIL.Image.Image image mode=RGB size=300x168>

# %%
# Cargo la imagen
imagen = cv2.imread('/content/sailoemoon.jpg')

# %%
# Define el kernel para el filtro sharpen
kernel = np.array([[-1,-1,-1],
                   [-1,8,-1],
                   [-1,-1,-1]])

# %%
# Aplico el filtro sharpen
image_sharpen = cv2.filter2D(imagen, -1, kernel)

# %%
# Mostrar la imagen original  y la iamgen sharpen
cv2_imshow(imagen)
cv2_imshow(image_sharpen)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=300x168>
# <PIL.Image.Image image mode=RGB size=300x168>
