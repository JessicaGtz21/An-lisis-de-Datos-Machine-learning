# %% [markdown]
# <a href="https://colab.research.google.com/github/JessicaGtz21/regresi-n-lineal-homicidios-/blob/main/ANALISIS_OFICINA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from seaborn import load_dataset
# dataset reporte de formatos
data = pd.read_excel("/content/reportedeformatos.xlsx")

import warnings
warnings.filterwarnings("ignore")
#reportedeformatos dataset
reportedeformatos = load_dataset("reportedeformatos")

# %%
data.head()
# Out:
#                  46559 Unnamed: 1 Unnamed: 2    Unnamed: 3 Unnamed: 4  \
# 0               TÍTULO        NaN        NaN  NOMBRE CORTO        NaN
# 1  Servicios ofrecidos        NaN        NaN      NLA95FXX        NaN
# 2                    1          4          4             2          9
# 3               393412     393413     393414        393399     393417
# 4         Tabla Campos        NaN        NaN           NaN        NaN
#
#   Unnamed: 5                                         Unnamed: 6 Unnamed: 7  \
# 0        NaN                                        DESCRIPCIÓN        NaN
# 1        NaN  La información para dar a conocer los servicio...        NaN
# 2          1                                                  2          1
# 3     393421                                             393401     393419
# 4        NaN                                                NaN        NaN
#
#   Unnamed: 8 Unnamed: 9  ... Unnamed: 22 Unnamed: 23 Unnamed: 24 Unnamed: 25  \
# ...

# %%
data.shape
# Out:
# (97, 32)

# %%
data.head()
# Out:
#                  46559 Unnamed: 1 Unnamed: 2    Unnamed: 3 Unnamed: 4  \
# 0               TÍTULO        NaN        NaN  NOMBRE CORTO        NaN
# 1  Servicios ofrecidos        NaN        NaN      NLA95FXX        NaN
# 2                    1          4          4             2          9
# 3               393412     393413     393414        393399     393417
# 4         Tabla Campos        NaN        NaN           NaN        NaN
#
#   Unnamed: 5                                         Unnamed: 6 Unnamed: 7  \
# 0        NaN                                        DESCRIPCIÓN        NaN
# 1        NaN  La información para dar a conocer los servicio...        NaN
# 2          1                                                  2          1
# 3     393421                                             393401     393419
# 4        NaN                                                NaN        NaN
#
#   Unnamed: 8 Unnamed: 9  ... Unnamed: 22 Unnamed: 23 Unnamed: 24 Unnamed: 25  \
# ...

# %%
data.sample(7)
# Out:
#    46559           Unnamed: 1           Unnamed: 2  \
# 68  2022  2022-12-01 00:00:00  2022-12-31 00:00:00
# 9   2022  2022-12-01 00:00:00  2022-12-31 00:00:00
# 66  2022  2022-12-01 00:00:00  2022-12-31 00:00:00
# 34  2022  2022-12-01 00:00:00  2022-12-31 00:00:00
# 14  2022  2022-12-01 00:00:00  2022-12-31 00:00:00
# 86  2022  2022-12-01 00:00:00  2022-12-31 00:00:00
# 75  2022  2022-12-01 00:00:00  2022-12-31 00:00:00
#
#                                            Unnamed: 3 Unnamed: 4  \
# 68                               Recolección de ramas    Directo
# 9                            Visto bueno de Simulacro    Directo
# 66                   Limpieza y desmalezado de plazas    Directo
# 34        Pláticas y brigadas de promoción a la salud    Directo
# 14           Canalización para Atención de Adicciones    Directo
# 86  Centros de atencion infantil (CAI) y estancias...    Directo
# 75                           Reparación de luminarias    Directo
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97 entries, 0 to 96
# Data columns (total 32 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   46559        97 non-null     object
#  1   Unnamed: 1   94 non-null     object
#  2   Unnamed: 2   94 non-null     object
#  3   Unnamed: 3   96 non-null     object
#  4   Unnamed: 4   94 non-null     object
#  5   Unnamed: 5   94 non-null     object
#  6   Unnamed: 6   96 non-null     object
#  7   Unnamed: 7   94 non-null     object
#  8   Unnamed: 8   94 non-null     object
#  9   Unnamed: 9   94 non-null     object
#  10  Unnamed: 10  94 non-null     object
#  11  Unnamed: 11  94 non-null     object
#  12  Unnamed: 12  94 non-null     object
#  13  Unnamed: 13  94 non-null     object
#  14  Unnamed: 14  94 non-null     object
#  15  Unnamed: 15  94 non-null     object
#  16  Unnamed: 16  94 non-null     object
#  17  Unnamed: 17  94 non-null     object
# ...

# %%
data.isnull().sum()
# Out:
# 46559           0
# Unnamed: 1      3
# Unnamed: 2      3
# Unnamed: 3      1
# Unnamed: 4      3
# Unnamed: 5      3
# Unnamed: 6      1
# Unnamed: 7      3
# Unnamed: 8      3
# Unnamed: 9      3
# Unnamed: 10     3
# Unnamed: 11     3
# Unnamed: 12     3
# Unnamed: 13     3
# Unnamed: 14     3
# Unnamed: 15     3
# Unnamed: 16     3
# Unnamed: 17     3
# Unnamed: 18     3
# Unnamed: 19     3
# Unnamed: 20     3
# Unnamed: 21     3
# Unnamed: 22     3
# Unnamed: 23     3
# Unnamed: 24     3
# Unnamed: 25     3
# Unnamed: 26     3
# Unnamed: 27    78
# Unnamed: 28     3
# Unnamed: 29     3
# Unnamed: 30     3
# Unnamed: 31     3
# dtype: int64

# %%
data.isnull().sum().sort_values(ascending=False).head()
# Out:
# Unnamed: 27    78
# Unnamed: 16     3
# Unnamed: 1      3
# Unnamed: 30     3
# Unnamed: 29     3
# dtype: int64

# %%
data.describe()
# Out:
#         46559           Unnamed: 1           Unnamed: 2    Unnamed: 3  \
# count      97                   94                   94            96
# unique      7                    4                    4            96
# top      2022  2022-12-01 00:00:00  2022-12-31 00:00:00  NOMBRE CORTO
# freq       91                   91                   91             1
#
#        Unnamed: 4             Unnamed: 5                       Unnamed: 6  \
# count          94                     94                               96
# unique          4                     27                               71
# top       Directo  Ciudadanía en General  Mejorar la imagen del municipio
# freq           91                     34                               16
#
#         Unnamed: 7                  Unnamed: 8      Unnamed: 9  ...  \
# count           94                          94              94  ...
# unique           5                          48              29  ...
# ...

# %%
data.duplicated().sum()
# Out:
# 0
